# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

# %%
# project is after 9-10 scrolls

# %%
x = np.linspace(0.1, 2 * np.pi, 41)
y = np.exp(np.sin(x))

# %%
x
# Out:
# array([0.1       , 0.25457963, 0.40915927, 0.5637389 , 0.71831853,
#        0.87289816, 1.0274778 , 1.18205743, 1.33663706, 1.49121669,
#        1.64579633, 1.80037596, 1.95495559, 2.10953522, 2.26411486,
#        2.41869449, 2.57327412, 2.72785376, 2.88243339, 3.03701302,
#        3.19159265, 3.34617229, 3.50075192, 3.65533155, 3.80991118,
#        3.96449082, 4.11907045, 4.27365008, 4.42822972, 4.58280935,
#        4.73738898, 4.89196861, 5.04654825, 5.20112788, 5.35570751,
#        5.51028714, 5.66486678, 5.81944641, 5.97402604, 6.12860567,
#        6.28318531])

# %%
y
# Out:
# array([1.10498683, 1.28638841, 1.48860305, 1.70633924, 1.93115757,
#        2.15156296, 2.35372172, 2.52284638, 2.64510234, 2.70969264,
#        2.71065097, 2.64788748, 2.52720475, 2.35927974, 2.15788679,
#        1.93781443, 1.71294765, 1.49486448, 1.29209894, 1.11003229,
#        0.95124924, 0.81615126, 0.70364081, 0.61174673, 0.53812353,
#        0.4804078 , 0.43644636, 0.40442535, 0.38293206, 0.3709766 ,
#        0.36799442, 0.37384318, 0.38880149, 0.41357117, 0.44927975,
#        0.49747353, 0.5600855 , 0.63935511, 0.73767062, 0.85730223,
#        1.        ])

# %%
plt.stem(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-13-f847fead5f52>:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(x,y)
# <StemContainer object of 3 artists>

# %%
# two different arrays
x = np.array([8,7,9,0])
y = np.array([-8,-7,15,16])
# needed for the graph below
my_range = np.arange(4)
# their respective means
mean_x = np.mean(x)
mean_y = np.mean(y)
fig, axs = plt.subplots(1,2, sharey=True)
axs[0].stem(my_range, x, label='x values', bottom=mean_x) 
axs[1].stem(my_range, y, label='y values', bottom=mean_y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-15-bb23be6b88ba>:10: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   axs[0].stem(my_range, x, label='x values', bottom=mean_x)
# <ipython-input-15-bb23be6b88ba>:11: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   axs[1].stem(my_range, y, label='y values', bottom=mean_y)

# %%
np.mean([70, 60, 100, 90, 55])
# Out:
# 75.0

# %%
x=10;

# %%
x
# Out:
# 10

# %%
data=[[34,24],[43,5],[81,36],[106,28],[115,49]]
my_data=np.array(data)
my_data
# Out:
# array([[ 34,  24],
#        [ 43,   5],
#        [ 81,  36],
#        [106,  28],
#        [115,  49]])

# %%
means=np.mean(my_data,0)
means
# Out:
# array([75.8, 28.4])

# %%
std=my_data.std(0)
std
# Out:
# array([32.55395521, 14.48585517])

# %%
plt.scatter(my_data[:,0],my_data[:,1])
plt.scatter(means[0],means[1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.patches as patch
ellipse=patch.Ellipse([means[0],means[1]],std[0]*2,std[1]*2,alpha=0.25)
fig,graphs=plt.subplots()
graphs.scatter(my_data[:,0],my_data[:,1])
graphs.scatter(means[0],means[1])
graphs.add_patch(ellipse)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(means)
print(std*2)
# Out:
# [75.8 28.4]
# [65.10791043 28.97171034]

# %%
help(patch.Ellipse)
# Out:
# Help on class Ellipse in module matplotlib.patches:
#
# class Ellipse(Patch)
#  |  Ellipse(xy, width, height, angle=0, **kwargs)
#  |
#  |  A scale-free ellipse.
#  |
#  |  Method resolution order:
#  |      Ellipse
#  |      Patch
#  |      matplotlib.artist.Artist
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, xy, width, height, angle=0, **kwargs)
#  |      Parameters
#  |      ----------
#  |      xy : (float, float)
#  |          xy coordinates of ellipse centre.
#  |      width : float
#  |          Total length (diameter) of horizontal axis.
#  |      height : float
#  |          Total length (diameter) of vertical axis.
#  |      angle : scalar, optional
#  |          Rotation in degrees anti-clockwise.
#  |
#  |      Notes
#  |      -----
#  |      Valid keyword arguments are:
#  |
#  |      Properties:
#  |          agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array
# ...

# %%
my_data
# Out:
# array([[ 34,  24],
#        [ 43,   5],
#        [ 81,  36],
#        [106,  28],
#        [115,  49]])

# %%
my_data-means
# Out:
# array([[-41.8,  -4.4],
#        [-32.8, -23.4],
#        [  5.2,   7.6],
#        [ 30.2,  -0.4],
#        [ 39.2,  20.6]])

# %%
means
# Out:
# array([75.8, 28.4])

# %%
np.linalg.norm(my_data-means)
# Out:
# 42.03094098399416

# %%
my_data
# Out:
# array([[ 34,  24],
#        [ 43,   5],
#        [ 81,  36],
#        [106,  28],
#        [115,  49]])

# %%
mini=np.min(my_data,0)
maxi=np.max(my_data,0)


print(mini,'\n',maxi)
# Out:
# [34  5]
#  [115  49]

# %%
normed=(my_data-mini)/(maxi-mini)
normed
# Out:
# array([[0.        , 0.43181818],
#        [0.11111111, 0.        ],
#        [0.58024691, 0.70454545],
#        [0.88888889, 0.52272727],
#        [1.        , 1.        ]])

# %%
means=np.mean(normed,0)
std=np.std(normed,0)
ellipse=patch.Ellipse([means[0],means[1]],std[0]*2,std[1]*2,alpha=0.25)

fig,graphs=plt.subplots()
graphs.scatter(normed[:,0],normed[:,1])
graphs.scatter(means[0],means[1])
graphs.add_patch(ellipse)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
my_data.mean(0)
# Out:
# array([75.8, 28.4])

# %%
np.mean(my_data,0)
# Out:
# array([75.8, 28.4])

# %% [markdown]
# ## Data

# %%
df=pd.read_csv('happyscore_income.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                111 non-null    object
#  1   adjusted_satisfaction  111 non-null    float64
#  2   avg_satisfaction       111 non-null    float64
#  3   std_satisfaction       111 non-null    float64
#  4   avg_income             111 non-null    float64
#  5   median_income          111 non-null    float64
#  6   income_inequality      111 non-null    float64
#  7   region                 111 non-null    object
#  8   happyScore             111 non-null    float64
#  9   GDP                    111 non-null    float64
#  10  country.1              111 non-null    object
# dtypes: float64(8), object(3)
# memory usage: 9.7+ KB

# %%
df.sample(5)
# Out:
#        country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 16      Canada                   69.0               8.0              1.71
# 84    Portugal                   47.0               5.8              2.16
# 68  Mauritania                   36.0               4.9              2.62
# 85    Paraguay                   56.0               6.8              2.04
# 34      France                   52.0               6.4              2.15
#
#       avg_income  median_income  income_inequality  \
# 16  20190.780000   16829.100000          33.790000
# 84   9982.875000    7800.645000          36.630000
# 68   1922.640000    1567.200000          35.690000
# 85   4938.520000    3136.040000          50.966667
# 34  18096.788571   14971.251429          32.255714
#
#                            region  happyScore      GDP   country.1
# 16                'North America'       7.427  1.32629      Canada
# 84               'Western Europe'       5.102  1.15991    Portugal
# ...

# %%
df.sort_values('avg_income',inplace=True)

# %%
richest=df[df['avg_income']>15000]
richest.head()
# Out:
#            country  adjusted_satisfaction  avg_satisfaction  std_satisfaction  \
# 49           Italy                   57.0               6.6              1.81
# 44         Ireland                   64.0               7.5              1.85
# 90          Sweden                   67.0               7.8              1.72
# 36  United Kingdom                   60.0               7.1              1.98
# 7          Belgium                   63.0               7.2              1.72
#
#     avg_income  median_income  income_inequality            region  \
# 49   15437.595      13163.070           34.12625  'Western Europe'
# 44   16657.770      13823.160           32.41875  'Western Europe'
# 90   17032.755      15166.605           26.95000  'Western Europe'
# 36   17099.550      14172.735           34.43250  'Western Europe'
# 7    17168.505      15166.455           28.74500  'Western Europe'
#
#     happyScore      GDP       country.1
# 49       5.948  1.25114           Italy
# ...

# %%
plt.scatter(richest['avg_income'],richest['happyScore'])
for k,i in richest.iterrows():
    plt.text(i['avg_income'],i['happyScore'],i['country'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# for k,i in richest.iterrows():
#     print(k,i['country'])
# Out:
# 49 Italy
# 44 Ireland
# 90 Sweden
# 36 United Kingdom
# 7 Belgium
# 33 Finland
# 27 Denmark
# 34 France
# 76 Netherlands
# 48 Iceland
# 25 Germany
# 3 Austria
# 4 Australia
# 16 Canada
# 77 Norway
# 105 United States
# 17 Switzerland
# 61 Luxembourg

# %%
plt.figure()
plt.xlabel('income')
plt.ylabel('happy score')
plt.scatter(df['avg_income'],df['happyScore'],s=df['income_inequality']*5,alpha=0.25)
plt.legend(['Inequality income country'],loc='upper left')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
happy=df['happyScore']
income=df['avg_income']
ineq=df['income_inequality']

# %%
happy
# Out:
# 10     2.905
# 65     3.681
# 58     4.571
# 72     4.971
# 73     3.845
#        ...
# 16     7.427
# 77     7.522
# 105    7.119
# 17     7.587
# 61     6.946
# Name: happyScore, Length: 111, dtype: float64

# %%
income
# Out:
# 10       572.880
# 65       574.200
# 58       653.040
# 72       714.720
# 73       718.400
#          ...
# 16     20190.780
# 77     21877.710
# 105    23127.000
# 17     23400.040
# 61     26182.275
# Name: avg_income, Length: 111, dtype: float64

# %%
from sklearn.cluster import KMeans


np.set_printoptions(suppress=True)
income_happy=np.column_stack((income,happy))

income_happy
# Out:
# array([[  572.88      ,     2.905     ],
#        [  574.2       ,     3.681     ],
#        [  653.04      ,     4.571     ],
#        [  714.72      ,     4.971     ],
#        [  718.4       ,     3.845     ],
#        [  850.08      ,     4.507     ],
#        [  870.84      ,     3.587     ],
#        [  903.3       ,     3.995     ],
#        [  908.64      ,     4.898     ],
#        [  910.32      ,     5.268     ],
#        [  936.36      ,     2.839     ],
#        [  941.4       ,     3.781     ],
#        [  946.52      ,     3.465     ],
#        [  956.76      ,     5.129     ],
#        [  989.04      ,     3.34      ],
#        [ 1050.72      ,     4.512     ],
#        [ 1126.48      ,     3.931     ],
#        [ 1135.08      ,     3.904     ],
#        [ 1177.68      ,     3.667     ],
#        [ 1265.34      ,     4.694     ],
#        [ 1357.848     ,     4.565     ],
#        [ 1428.12      ,     4.514     ],
#        [ 1448.88      ,     4.033     ],
# ...

# %%
kmeanres=KMeans(n_clusters=3).fit(income_happy)

# %%
kmeanres.cluster_centers_
# Out:
# array([[ 2199.1212108 ,     4.75472308],
#        [18759.30217857,     7.0327    ],
#        [ 7577.55711256,     5.85080769]])

# %%
clustercen=kmeanres.cluster_centers_
plt.figure()
plt.scatter(income,happy)
plt.scatter(clustercen[:,0],clustercen[:,1],s=1200)
# Out:
# <img src="data:image/png;base64,..." width="640">
